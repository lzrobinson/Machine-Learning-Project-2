# %%
import pandas as pd
import numpy as np
from sklearn.naive_bayes import GaussianNB
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import StratifiedKFold


import pandas as pd
import numpy as np
from sklearn.naive_bayes import GaussianNB
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import make_pipeline

def train_naive_bayes(X, y):
    # Splitting the DataFrame into numerical and non-numerical features
    numerical_features = X.select_dtypes(include=['float', 'int'])
    non_numerical_features = X.select_dtypes(exclude=['float', 'int'])

    # Impute missing values in numerical features
    imputer = SimpleImputer(strategy='mean')
    imputed_numerical_features = imputer.fit_transform(numerical_features)

    # One-hot encoding for non-numerical features
    encoder = OneHotEncoder(handle_unknown='ignore')
    encoded_non_numerical_features = encoder.fit_transform(non_numerical_features)

    # Combining numerical and encoded non-numerical features
    processed_X = np.concatenate((imputed_numerical_features, encoded_non_numerical_features.toarray()), axis=1)

    # Creating the ColumnTransformer to handle numeric and categorical columns separately
    transformer = ColumnTransformer(
        transformers=[
            ('num', make_pipeline(SimpleImputer(strategy='mean')), numerical_features.columns),
            ('cat', OneHotEncoder(handle_unknown='ignore'), non_numerical_features.columns)
        ],
        remainder='passthrough'
    )

    # Creating the Naive Bayes classifier pipeline
    classifier = make_pipeline(transformer, GaussianNB())

    # Training the classifier
    classifier.fit(X, y)

    return classifier


def perform_cross_validation(X, y, n_splits=5, random_state=3):
    def cross_val_naive_bayes(X, y, n_splits=5, random_state=None):
    # Splitting the DataFrame into numerical and non-numerical features
    numerical_features = X.select_dtypes(include=['float', 'int'])
    non_numerical_features = X.select_dtypes(exclude=['float', 'int'])

    # Combining X and y into a single DataFrame
    combined_data = pd.concat([X, y], axis=1)

    # One-hot encoding for non-numerical features
    encoder = OneHotEncoder()
    encoded_data = encoder.fit_transform(combined_data[non_numerical_features.columns])

    # Separating the encoded data back into X and y
    encoded_X = encoded_data[:, :-1]
    encoded_y = encoded_data[:, -1]

    # Initializing lists to store the evaluation metrics for each fold
    accuracies = []

    # Creating the cross-validation splitter
    cv = StratifiedKFold(n_splits=n_splits, random_state=random_state, shuffle=True)

    # Perform cross-validation
    for train_index, test_index in cv.split(X, y):
        # Splitting the data into training and test sets
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]

        # One-hot encoding for non-numerical features
        X_train_encoded = encoder.transform(X_train[non_numerical_features.columns])
        X_test_encoded = encoder.transform(X_test[non_numerical_features.columns])

        # Impute missing values in numerical features
        imputer = SimpleImputer(strategy='mean')
        X_train_numerical = imputer.fit_transform(X_train[numerical_features.columns])
        X_test_numerical = imputer.transform(X_test[numerical_features.columns])

        # Combining numerical and encoded non-numerical features
        X_train_processed = np.concatenate((X_train_numerical, X_train_encoded.toarray()), axis=1)
        X_test_processed = np.concatenate((X_test_numerical, X_test_encoded.toarray()), axis=1)

        # Creating the Naive Bayes classifier
        classifier = GaussianNB()

        # Training the classifier
        classifier.fit(X_train_processed, y_train)

        # Making predictions on the test set
        y_pred = classifier.predict(X_test_processed)

        # Computing accuracy score
        accuracy = accuracy_score(y_test, y_pred)
        accuracies.append(accuracy)

    return np.mean(accuracies)

'''
# Example usage:
X = ...  # Your pandas DataFrame containing the features
y = ...  # Your corresponding Series containing the class labels
categorical_features = [...]  # List of categorical feature column names

# Perform cross-validation and get the scores
cv_scores = perform_cross_validation(X, y, categorical_features, num_folds=5)

# Print the scores
print("Cross-Validation Scores:", cv_scores)
print("Mean Score:", np.mean(cv_scores))
print("Standard Deviation:", np.std(cv_scores))



# Example usage:
X = ...  # Your pandas DataFrame containing the features
y = ...  # Your corresponding Series containing the class labels
categorical_features = [...]  # List of categorical feature column names

classifier = train_naive_bayes(X, y, categorical_features)

# Making predictions on new data
new_data = ...  # Your new data as a DataFrame
predictions = classifier.predict(new_data)'''
# Out:
#   Cell In[60], line 63
#     numerical_features = X.select_dtypes(include=['float', 'int'])
#     ^
# IndentationError: expected an indented block after function definition on line 61

# %%
#################Testing Stuff##############

        
data = pd.read_csv("Data/book_rating_train.csv")


data.pop("PublishDay")
data.pop("PublishMonth")
data.pop("Name")
data.pop("Description")
data.pop("Authors")



book_name_features = pd.read_csv(r"Data/book_text_features_doc2vec/train_name_doc2vec100.csv", index_col = False, delimiter = ',', header=None)
add_letter_to_cols(book_name_features, "n")

book_desc_features = pd.read_csv(r"Data/book_text_features_doc2vec/train_desc_doc2vec100.csv", index_col = False, delimiter = ',', header=None)
add_letter_to_cols(book_desc_features, "d")

book_auth_features = pd.read_csv(r"Data/book_text_features_doc2vec/train_authors_doc2vec20.csv", index_col = False, delimiter = ',', header=None)
add_letter_to_cols(book_auth_features, "a")

langs = learnLanguage(data, book_desc_features)
data['Language'] = langs

label_encoder = LabelEncoder()
data['Publisher'] = label_encoder.fit_transform(data['Publisher'])


data = pd.concat([book_name_features, book_auth_features, book_desc_features, data], axis=1)

data.columns = data.columns.astype(str)

data.fillna(data.mean(), inplace=True)  # Example: Replace missing values with column means
data.fillna('Unknown', inplace=True)  # Example: Replace missing values with 'Unknown'

print(data)


y = data.pop("rating_label")

#print(data)
#has_nans = data.isna().any().any()
#print(has_nans)

#nan_values = data[data.isna()]
#print(nan_values)

cv_scores = perform_cross_validation(data, y, n_splits = 5)

# Print the scores
#print("Cross-Validation Scores:", cv_scores)
#print("Mean Score:", np.mean(cv_scores))
#print("Standard Deviation:", np.std(cv_scores))
# Out:
# C:\Users\mattb\AppData\Local\Temp\ipykernel_1796\3858427493.py:35: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.fillna(data.mean(), inplace=True)  # Example: Replace missing values with column means
#              n0        n1        n2        n3        n4        n5        n6  \
# 0      0.052262 -0.263308  0.026872  0.128574 -0.161565 -0.127520  0.249588
# 1     -0.129112  0.021312  0.159166 -0.072448  0.036028 -0.093721  0.129199
# 2     -0.170058  0.052351 -0.013406  0.099001  0.083173 -0.161439  0.048635
# 3      0.250849  0.021555  0.091047 -0.041589 -0.040949  0.240260  0.415056
# 4     -0.041681  0.038051 -0.051164 -0.076813  0.096855 -0.215943  0.152729
# ...         ...       ...       ...       ...       ...       ...       ...
# ...

# %%
###############Helper stuff##############

'''Seems to be a good model, has good counts, verified a few instances seems to perform great in fact'''
def learnLanguage(data, doc2vec):
    
    
    X = doc2vec
    y = data['Language']
    
    y = pd.Series(y)
    # Assuming you have a feature matrix `X` and a target variable `y`
    # X should contain other features like doc2vec and word frequency counts
    # y should contain the language labels (with missing values)

    # Split the dataset into instances with and without missing language values
    X_with_language = X[~y.isnull()]
    y_with_language = y[~y.isnull()]
    X_missing_language = X[y.isnull()]

    # Split the dataset with language into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(X_with_language, y_with_language, test_size=0.2, random_state=42)

    # Train a Random Forest classifier on the instances with language
    rf = RandomForestClassifier()
    rf.fit(X_train, y_train)

    # Predict the missing language values using the trained model
    imputed_language = rf.predict(X_missing_language)

    # Merge the imputed language values with the original dataset
    y[y.isnull()] = imputed_language

    # Now you can proceed with your machine learning algorithm using the complete dataset
    return y



def add_letter_to_cols(df, letter):
    for column in df.columns:
        new_name = letter + str(column)
        df.rename(columns={column: new_name}, inplace=True)
